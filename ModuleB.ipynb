# %% [markdown]
# <a href="https://colab.research.google.com/github/mal-bertsen/MAT421/blob/main/ModuleB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# interpolation problem statement

# %%
#While regression is a method that attmepts to minimize residual and error values to model data. Interpolation goes through all of the data points available.

import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')

x = [1,2,3,4]
y = [1,5,3,4]
plt.figure(figsize = (7,5))
plt.plot(x,y,'bo', 1.5,3,'ro')
plt.title('Data points')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# <ipython-input-6-822bc7ed360c>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %% [markdown]
# Linear interpolation

# %%
#In linear interpolation, the estimated point is assumed to lie on the line joining the nearest points to the left and right.
#For example,
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')
x = [1, 2, 3, 4]
y = [1, 5, 3, 4]

f = interp1d(x, y)
y_hat = f(1.5)
print(y_hat)
plt.figure(figsize = (7,5))
plt.plot(x, y, '-ob')
plt.plot(1.5, y_hat, 'ro')
plt.title('Linear Interpolation at x = 1.5')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#Note that linear interpolation can result in sharp curves, which are not the most satisfying.
# Out:
# <ipython-input-3-f2b70e94f3a4>:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')
# 3.0

# %% [markdown]
# Cubic spline interpolation

# %%
#In cubic spline interpolation, the interpolating function is a set of piecewise cubic functions.

from scipy.interpolate import CubicSpline
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')

x = [1,1.5, 2, 3, 4]
y = [1,3, 5, 3, 4]

f = CubicSpline(x, y, bc_type='natural')
x_new = np.linspace(0, 5, 100)
y_new = f(x_new)
plt.figure(figsize = (10,8))
plt.plot(x_new, y_new, 'b')
plt.plot(x, y, 'bo')
plt.plot(1.5, y_hat, 'ro')
plt.title('Cubic Spline Interpolation')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# <ipython-input-14-78d2332cbb20>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')
